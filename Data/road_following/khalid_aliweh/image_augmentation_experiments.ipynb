# %% [markdown]
# # Image Augmentation experiments using pillow and skimage

# %%
import glob
import PIL
from PIL import ImageEnhance
# from PIL import Image
import skimage
import cv2
import random
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
image_paths = glob.glob(os.path.join('dataset_xy', '*.jpg'))

# %%
original_image = PIL.Image.open(image_paths[0])
original_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x1F18FFBE148>

# %% [markdown]
# ## PIL image enhancers

# %%
enhancer = ImageEnhance.Brightness(original_image)
plt.imshow(enhancer.enhance(3))

# %%
enhancer = ImageEnhance.Brightness(original_image)
plt.imshow(enhancer.enhance(0.4))

# %% [markdown]
# ## Pillow image filters

# %%
plt.imshow(PIL.Image.open(image_paths[0]).filter(PIL.ImageFilter.GaussianBlur(5)))

# %%
plt.imshow(PIL.Image.open(image_paths[0]).filter(PIL.ImageFilter.BoxBlur(5)))

# %%
plt.imshow(PIL.Image.open(image_paths[0]).filter(PIL.ImageFilter.UnsharpMask(7)))

# %%
plt.imshow(PIL.Image.open(image_paths[0]).filter(PIL.ImageFilter.ModeFilter(7)))

# %%
plt.imshow(PIL.Image.open(image_paths[0]).filter(PIL.ImageFilter.MinFilter(5)))

# %%
plt.imshow(PIL.Image.open(image_paths[0]).filter(PIL.ImageFilter.MaxFilter(5)))

# %%
plt.imshow(PIL.Image.open(image_paths[0]).filter(PIL.ImageFilter.FIND_EDGES()))

# %%
plt.imshow(PIL.Image.open(image_paths[0]).filter(PIL.ImageFilter.EDGE_ENHANCE_MORE()))

# %%
plt.imshow(PIL.Image.open(image_paths[0]).filter(PIL.ImageFilter.EMBOSS()))

# %%
plt.imshow(PIL.Image.open(image_paths[0]).filter(PIL.ImageFilter.EDGE_ENHANCE_MORE()))

# %%
plt.imshow(PIL.Image.open(image_paths[0]).filter(PIL.ImageFilter.DETAIL()))

# %%
plt.imshow(PIL.Image.open(image_paths[0]).filter(PIL.ImageFilter.CONTOUR()))

# %% [markdown]
# ## Adding noise using skimage

# %%
import skimage
import skimage.io as io
import matplotlib.pyplot as plt
img_path=image_paths[0]
img = io.imread(img_path)/255.0

def plotnoise(img, mode, r, c, i):
    plt.subplot(r,c,i)
    if mode is not None:
        gimg = skimage.util.random_noise(img, mode=mode)
        plt.imshow(gimg)
    else:
        plt.imshow(img)
    plt.title(mode)
    plt.axis("off")

plt.figure(figsize=(18,24))
r=4
c=2
plotnoise(img, "gaussian", r,c,1)
plotnoise(img, "poisson", r,c,3)
plotnoise(img, "salt", r,c,4)
plotnoise(img, "pepper", r,c,5)



plotnoise(img, "localvar", r,c,2)

plotnoise(img, "s&p", r,c,6)
plotnoise(img, "speckle", r,c,7)
plotnoise(img, None, r,c,8)
plt.show()
